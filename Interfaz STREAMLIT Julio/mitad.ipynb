# %%
import streamlit as st
import pandas as pd
import math
import numpy as np 
import matplotlib.pyplot as plt

# %%
@st.cache_data
def distance(x, y, z):
  return math.sqrt(x**2 + y**2 + z**2)

df_p7s1 = pd.read_csv('P07_Sesion1.csv')
df_p7s1["time"] = df_p7s1.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p7s1.columns):
  df_p7s1['Distancia'] = df_p7s1.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()
df_p7s2 = pd.read_csv('P07_Sesion2.csv')
df_p7s2["time"] = df_p7s2.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p7s2.columns):
  df_p7s2['Distancia'] = df_p7s2.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()
df_p7s3 = pd.read_csv('P07_Sesion3.csv')
df_p7s3["time"] = df_p7s3.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p7s3.columns):
  df_p7s3['Distancia'] = df_p7s3.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()
df_p7s4 = pd.read_csv('P07_Sesion4.csv')
df_p7s4["time"] = df_p7s4.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p7s4.columns):
  df_p7s4['Distancia'] = df_p7s4.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()
df_p8s1 = pd.read_csv('P08_Sesion1.csv')
df_p8s1["time"] = df_p8s1.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p8s1.columns):
  df_p8s1['Distancia'] = df_p8s1.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()
df_p8s2 = pd.read_csv('P08_Sesion2.csv')
df_p8s2["time"] = df_p8s2.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p8s2.columns):
  df_p8s2['Distancia'] = df_p8s2.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()

df_p8s3 = pd.read_csv('P08_Sesion3.csv')
df_p8s3["time"] = df_p8s3.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p8s3.columns):
  df_p8s3['Distancia'] = df_p8s3.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()

df_p8s4 = pd.read_csv('P08_Sesion4.csv')
df_p8s4["time"] = df_p8s4.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p8s4.columns):
  df_p8s4['Distancia'] = df_p8s4.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()

df_p11s1 = pd.read_csv('P11_Sesion1.csv')
df_p11s1["time"] = df_p11s1.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p11s1.columns):
  df_p11s1['Distancia'] = df_p11s1.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()

df_p11s2 = pd.read_csv('P11_Sesion2.csv')
df_p11s2["time"] = df_p11s2.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p11s2.columns):
  df_p11s2['Distancia'] = df_p11s2.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()

df_p11s3 = pd.read_csv('P11_Sesion3.csv')
df_p11s3["time"] = df_p11s3.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p11s3.columns):
  df_p11s3['Distancia'] = df_p11s3.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()

df_p11s4 = pd.read_csv('P11_Sesion4.csv')
df_p11s4["time"] = df_p11s4.index * 3
if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p11s4.columns):
  df_p11s4['Distancia'] = df_p11s4.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
else:
  st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
  st.stop()
paciente7=[]
paciente7.append(df_p7s1)
paciente7.append(df_p7s2)
paciente7.append(df_p7s3)
paciente7.append(df_p7s4)
paciente8=[]
paciente8.append(df_p8s1)
paciente8.append(df_p8s2)
paciente8.append(df_p8s3)
paciente8.append(df_p8s4)
paciente11=[]
paciente11.append(df_p11s1)
paciente11.append(df_p11s2)
paciente11.append(df_p11s3)
paciente11.append(df_p11s4)
sesiones=['Sesion 1','Sesion 2','Sesion 3','Sesion 4']
st.sidebar.subheader('Seleccione un paciente')
var=st.sidebar.selectbox(label='Pacientes', options=['Paciente 7', 'Paciente 8', 'Paciente 11'])

if 'Paciente 7' in var:
  st.title('Distancia recorrida Paciente 7')
  valores=[]
  for i in range(len(paciente7)):
    valores.append(sum(paciente7[i]['Distancia']))
  fig1, ax1 = plt.subplots()
  ax1.bar(sesiones,valores)
  ax1.set_title('Distancia recorrida por sesión')
  ax1.set_xlabel('Sesiones')
  ax1.set_ylabel('Distancia recorrida')
  st.pyplot(fig1)
if 'Paciente 8' in var:
  st.title('Distancia recorrida Paciente 8')
  valores=[]
  for i in range(len(paciente8)):
    valores.append(sum(paciente8[i]['Distancia']))
  fig2, ax2 = plt.subplots()
  ax2.bar(sesiones,valores)
  ax2.set_title('Distancia recorrida por sesión')
  ax2.set_xlabel('Sesiones')
  ax2.set_ylabel('Distancia recorrida')
  st.pyplot(fig2)
if 'Paciente 11' in var:
  st.title('Distancia recorrida Paciente 11')
  valores=[]
  for i in range(len(paciente11)):
    valores.append(sum(paciente11[i]['Distancia']))
  fig3, ax3 = plt.subplots()
  ax3.bar(sesiones,valores)
  ax3.set_title('Distancia recorrida por sesión')
  ax3.set_xlabel('Sesiones')
  ax3.set_ylabel('Distancia recorrida')
  st.pyplot(fig3)
# Out:
# 2024-11-21 14:00:13.515 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2024-11-21 14:00:13.538 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.714
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Users/juliooo/Library/Python/3.12/lib/python/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2024-11-21 14:00:13.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.715 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.716 No runtime found, using MemoryCacheStorageManager
# 2024-11-21 14:00:13.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.720 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.722 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.724 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.725 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.727 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.728 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.732 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.734 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.736 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.738 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.740 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.741 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.742 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.744 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.745 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.747 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.751 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.755 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.756 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.795 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.796 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.797 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.798 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.799 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.802 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.810 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.812 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.813 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.814 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.815 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.818 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.841 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.847 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.902 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.903 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.904 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.906 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.907 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.908 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.910 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.913 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.914 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.915 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.916 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.918 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.919 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.920 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.921 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.923 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.924 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.927 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.929 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.933 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.937 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.938 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.940 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.941 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.943 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.944 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.947 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.949 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.954 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.962 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.968 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.969 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.970 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.971 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.972 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.974 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:13.977 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.179 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.180 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.185 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.244 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.249 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.251 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.252 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.255 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.257 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.261 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.262 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.263 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.265 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.268 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.272 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.274 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.277 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.278 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.279 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.281 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.283 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.287 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.294 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.301 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.303 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.304 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.306 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.310 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.311 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.313 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.317 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.318 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.320 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.323 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.325 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.327 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.329 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.336 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:14.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
# 2024-11-21 14:00:35.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.198 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.221 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.229 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.312 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.314 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-21 14:00:35.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 15
#      13 df_p7s2["time"] = df_p7s2.index * 3
#      14 if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p7s2.columns):
# ---> 15   df_p7s2['Distancia'] = df_p7s2.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
#      16 else:
#      17   st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[2], line 15, in <lambda>(row)
#      13 df_p7s2["time"] = df_p7s2.index * 3
#      14 if {'Des_x', 'Des_y', 'Des_z'}.issubset(df_p7s2.columns):
# ---> 15   df_p7s2['Distancia'] = df_p7s2.apply(lambda row: distance(row['Des_x'], row['Des_y'], row['Des_z']), axis=1)
#      16 else:
#      17   st.error("Las columnas 'Des_x', 'Des_y', y 'Des_z' necesarias para calcular la distancia no están presentes.")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/caching/cache_utils.py:216, in CachedFunc.__call__(self, *args, **kwargs)
#     213     message = self._info.show_spinner
#     215 if self._info.show_spinner or isinstance(self._info.show_spinner, str):
# --> 216     with spinner(message, _cache=True):
#     217         return self._get_or_create_cached_value(args, kwargs)
#     218 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/spinner.py:48, in spinner(text, _cache)
#      45 from streamlit.proto.Spinner_pb2 import Spinner as SpinnerProto
#      46 from streamlit.string_util import clean_text
# ---> 48 message = st.empty()
#      50 # Set the message 0.5 seconds in the future to avoid annoying
#      51 # flickering if this spinner runs too quickly.
#      52 DELAY_SECS = 0.5
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/metrics_util.py:410, in gather_metrics.<locals>.wrapped_func(*args, **kwargs)
#     408         _LOGGER.debug("Failed to collect command telemetry", exc_info=ex)
#     409 try:
# --> 410     result = non_optional_func(*args, **kwargs)
#     411 except RerunException as ex:
#     412     # Duplicated from below, because static analysis tools get confused
#     413     # by deferring the rethrow.
#     414     if tracking_activated and command_telemetry:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/elements/empty.py:100, in EmptyMixin.empty(self)
#      30 """Insert a single-element container.
#      31
#      32 Inserts a container into your app that can be used to hold a single element.
#    (...)
#      97
#      98 """
#      99 empty_proto = EmptyProto()
# --> 100 return self.dg._enqueue("empty", empty_proto)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/delta_generator.py:464, in DeltaGenerator._enqueue(self, delta_type, element_proto, add_rows_metadata, user_key)
#     462 # Only enqueue message and fill in metadata if there's a container.
#     463 msg_was_enqueued = False
# --> 464 if dg._root_container is not None and dg._cursor is not None:
#     465     msg.metadata.delta_path[:] = dg._cursor.delta_path
#     467     _enqueue_message(msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/delta_generator.py:391, in DeltaGenerator._cursor(self)
#     386 """Return our Cursor. This will be None if we're not running in a
#     387 ScriptThread - e.g., if we're running a "bare" script outside of
#     388 Streamlit.
#     389 """
#     390 if self._provided_cursor is None:
# --> 391     return cursor.get_container_cursor(self._root_container)
#     392 else:
#     393     return self._provided_cursor
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/cursor.py:43, in get_container_cursor(root_container)
#      40 if root_container is None:
#      41     return None
# ---> 43 ctx = get_script_run_ctx()
#      45 if ctx is None:
#      46     return None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/streamlit/runtime/scriptrunner_utils/script_run_context.py:259, in get_script_run_ctx(suppress_warning)
#     253 ctx: ScriptRunContext | None = getattr(thread, SCRIPT_RUN_CONTEXT_ATTR_NAME, None)
#     254 if ctx is None and not suppress_warning:
#     255     # Only warn about a missing ScriptRunContext if suppress_warning is False, and
#     256     # we were started via `streamlit run`. Otherwise, the user is likely running a
#     257     # script "bare", and doesn't need to be warned about streamlit
#     258     # bits that are irrelevant when not connected to a session.
# --> 259     _LOGGER.warning(
#     260         "Thread '%s': missing ScriptRunContext! This warning can be ignored when "
#     261         "running in bare mode.",
#     262         thread.name,
#     263     )
#     265 return ctx
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1551, in Logger.warning(self, msg, *args, **kwargs)
#    1542 """
#    1543 Log 'msg % args' with severity 'WARNING'.
#    1544
#    (...)
#    1548 logger.warning("Houston, we have a %s", "bit of a problem", exc_info=True)
#    1549 """
#    1550 if self.isEnabledFor(WARNING):
# -> 1551     self._log(WARNING, msg, args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1684, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1681         exc_info = sys.exc_info()
#    1682 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1683                          exc_info, func, extra, sinfo)
# -> 1684 self.handle(record)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1700, in Logger.handle(self, record)
#    1698 if isinstance(maybe_record, LogRecord):
#    1699     record = maybe_record
# -> 1700 self.callHandlers(record)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1762, in Logger.callHandlers(self, record)
#    1760     found = found + 1
#    1761     if record.levelno >= hdlr.level:
# -> 1762         hdlr.handle(record)
#    1763 if not c.propagate:
#    1764     c = None    #break out
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1028, in Handler.handle(self, record)
#    1026 self.acquire()
#    1027 try:
# -> 1028     self.emit(record)
#    1029 finally:
#    1030     self.release()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1164, in StreamHandler.emit(self, record)
#    1162     # issue 35046: merged two stream.writes into one.
#    1163     stream.write(msg + self.terminator)
# -> 1164     self.flush()
#    1165 except RecursionError:  # See issue 36272
#    1166     raise
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:1146, in StreamHandler.flush(self)
#    1144         self.stream.flush()
#    1145 finally:
# -> 1146     self.release()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/logging/__init__.py:975, in Handler.release(self)
#     972     if self.lock:
#     973         self.lock.acquire()
# --> 975 def release(self):
#     976     """
#     977     Release the I/O thread lock.
#     978     """
#     979     if self.lock:
#
# KeyboardInterrupt:

# %%
# !streamlit run app.py & npx localtunnel --port 8501 & curl ipv4.icanhazip.com
# Out:
# 35.231.203.182
#
# Collecting usage statistics. To deactivate, set browser.gatherUsageStats to false.
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://35.231.203.182:8501
#
# your url is: https://purple-trees-brush.loca.lt
#   Stopping...
